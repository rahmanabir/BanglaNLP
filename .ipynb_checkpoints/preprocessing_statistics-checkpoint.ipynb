# %% [markdown]
# ## Metadata Access

# %%
import numpy as np
# import pyaudio
import audio_metadata
from os import listdir
from os.path import isfile, join
import matplotlib.pyplot as plt

data_path = 'data/crblp/wav/'
audiofiles = [join(data_path,f) for f in listdir(data_path) if isfile(join(data_path, f))]

# %%
print(audiofiles[0])
print(len(audiofiles))

# %%
metadata = audio_metadata.load(audiofiles[0])
print(metadata, '\n')
print(type(metadata.streaminfo.duration))
print(metadata.streaminfo.duration,'in seconds')

# %%
listofdurations = []
countofbadwaves = 0
for wavfile in audiofiles:
    try:
        meta = audio_metadata.load(wavfile)
        listofdurations.append(meta.streaminfo.duration)
    except:
        countofbadwaves += 1
        print(wavfile,'has bad header')

print('Length of Wavfile Durations List:',len(listofdurations))
print('No. of Bad header Wavfiles:',countofbadwaves)

# %% [markdown]
# ## Duration Stats

# %%
listofdurations.sort()
print('Audio Time Stats')
print('----------------')
print('Size of Array:',len(listofdurations))
print('Maximum:',round(max(listofdurations),2))
print('Minimum:',round(min(listofdurations),2))
print('Mean',round(sum(listofdurations)/len(listofdurations),2))
print('Median:',round(listofdurations[int(len(listofdurations)/2)],2))
print('LoQuart:',round(listofdurations[int(len(listofdurations)/2) - int(len(listofdurations)/4)],2))
print('UpQuart:',round(listofdurations[int(len(listofdurations)/2) + int(len(listofdurations)/4)],2))

# %%
plt.figure(figsize=(16,8))
from matplotlib import pyplot as plt

# data = np.random.normal(0, 20, 1000) 
data = listofdurations

# fixed bin size
bins = np.arange(0, 20, 0.1) # fixed bin size

plt.xlim([0, 20])

plt.hist(data, bins=bins, alpha=0.5)
plt.title('Audio Playback Time Distribution')
plt.xticks(np.arange(0, 20, 1.0))
plt.xlabel('Playback Time')
plt.ylabel('File Count')

plt.show()

# %% [markdown]
# ## File Ranging

# %%
validtimes = []
for f in audiofiles:
    try:
        t = audio_metadata.load(f).streaminfo.duration
        if t>=1 and t<=2:
            validtimes.append(f)
    except:
        print('Bad Header:',f)
        
print(len(validtimes))
print(validtimes[0])
print(validtimes[len(validtimes)-1])

# %%
file = open('data_RangedAudiofileList_1to2.txt','w') 
for f in validtimes:
    file.write(f)
    file.write('\n')
file.close()

# %% [markdown]
# ## Character Frequency Distribution

# %%
import csv
import data_dekhabet as dkb
lookup = dkb.tokenlookup
leng = len(lookup)
countlook = [0]*leng


print(lookup)
print(leng)
print(countlook)

# %%
csvf = 'dekhabet_dataLabelsRanged.csv'
counter = []
with open(csvf, 'r') as csvFile:
    reader = csv.reader(csvFile)
    for row in reader:
        ctext = []
        text = row[4]
        text = text.strip("'-!$[]")
        text = text.split(',')
        i=0
        if 'Tokens' in text:
            pass
        else:
            for t in range(0,len(text)):
                i = int(text[t])
                counter.append(lookup[i])
csvFile.close()

# %%
import pandas
from collections import Counter
# a = ['a', 'a', 'a', 'a', 'b', 'b', 'c', 'c', 'c', 'd', 'e', 'e', 'e', 'e', 'e']
letter_counts = Counter(counter)
print(letter_counts)
df = pandas.DataFrame.from_dict(letter_counts, orient='index')
df.plot(kind='bar',figsize=(8,6))

# %% [markdown]
# # Google OpenSLR Stats

# %%
import pandas as pd
slrtsv_path = 'data/asr_bengali/utt_spk_text.tsv'
df = pd.read_csv(slrtsv_path, sep='\t')
df
# Out:
#           Filename    UID                         Transcript
# 0       000020a912  16cfb            বাংলাদেশে দায়িত্ব নেবে
# 1       000039928e  976b1                এ ধরণের কার্ড নিয়ে
# 2       00005debc7  f83df                  হতে উপার্জিত অর্থ
# 3       00009e687c  9813c              হাসির বিষয় হয়েই আছে
# 4       00012843bc  7ec1c                    সার্ক দেশগুলোতে
# ...            ...    ...                                ...
# 127560  ffff6a7f59  77f82  সংস্কৃতি মন্ত্রী আবুল কালাম আযাদও
# 127561  ffff98efe5  80539                      অভিযোগ রয়েছে
# 127562  ffffc017a0  15a75             আন্তোনিও দা মাগদালেনার
# 127563  ffffe3b62d  10a9f                          মি. খানের
# 127564  fffff1c677  06e62   কাজী নজরুলের লেখা হিন্দু-মুসলমান
#
# [127565 rows x 3 columns]

# %% [markdown]
# ### Find unique characters

# %%
listofuniques = []
engletters = 'qwertyuiopasdfghjklzxcvbnmQWERTYUIOPASDFGHJKLZXCVBNM1234567890-…,!?“'
for index, row in df.iterrows():
    if index%10000==0:
        print(index,listofuniques)
    for c in row[2]:
        if c not in engletters and len(c) <= 1:
            if c not in listofuniques:
                listofuniques.append(c)
listofuniques.sort()
print(listofuniques, len(listofuniques))
# Out:
# 0 []
# 10000 ['এ', ' ', 'ধ', 'র', 'ণ', 'ে', 'ক', 'া', '্', 'ড', 'ন', 'ি', 'য', '়', 'হ', 'ত', 'উ', 'প', 'জ', 'অ', 'থ', 'স', 'ব', 'ষ', 'ই', 'আ', 'ছ', 'দ', 'শ', 'গ', 'ু', 'ল', 'ো', 'ও', 'ভ', 'ী', 'ট', 'ূ', 'ম', 'ৈ', 'ৃ', 'ঙ', 'খ', 'ঃ', '১', '৯', '৬', '০', '২', 'ং', 'চ', 'ঘ', 'ৎ', '৫', '৪', '‘', '’', 'ফ', 'ৌ', '৮', 'ঁ', 'য়', '৩', 'ঢ', 'ঠ', '৭', ':', '।', '.', 'ড়', 'ঝ', '/', 'ঞ', '\u200c', '\x94', '"', "'", 'ঔ', 'ঈ', '\u200d', 'ঐ', '\x93', 'ঋ', '\n', '\t', '%', '”', 'ঊ']
# 20000 ['এ', ' ', 'ধ', 'র', 'ণ', 'ে', 'ক', 'া', '্', 'ড', 'ন', 'ি', 'য', '়', 'হ', 'ত', 'উ', 'প', 'জ', 'অ', 'থ', 'স', 'ব', 'ষ', 'ই', 'আ', 'ছ', 'দ', 'শ', 'গ', 'ু', 'ল', 'ো', 'ও', 'ভ', 'ী', 'ট', 'ূ', 'ম', 'ৈ', 'ৃ', 'ঙ', 'খ', 'ঃ', '১', '৯', '৬', '০', '২', 'ং', 'চ', 'ঘ', 'ৎ', '৫', '৪', '‘', '’', 'ফ', 'ৌ', '৮', 'ঁ', 'য়', '৩', 'ঢ', 'ঠ', '৭', ':', '।', '.', 'ড়', 'ঝ', '/', 'ঞ', '\u200c', '\x94', '"', "'", 'ঔ', 'ঈ', '\u200d', 'ঐ', '\x93', 'ঋ', '\n', '\t', '%', '”', 'ঊ', 'ৗ', '–', ';']
# ['এ', ' ', 'ধ', 'র', 'ণ', 'ে', 'ক', 'া', '্', 'ড', 'ন', 'ি', 'য', '়', 'হ', 'ত', 'উ', 'প', 'জ', 'অ', 'থ', 'স', 'ব', 'ষ', 'ই', 'আ', 'ছ', 'দ', 'শ', 'গ', 'ু', 'ল', 'ো', 'ও', 'ভ', 'ী', 'ট', 'ূ', 'ম', 'ৈ', 'ৃ', 'ঙ', 'খ', 'ঃ', '১', '৯', '৬', '০', '২', 'ং', 'চ', 'ঘ', 'ৎ', '৫', '৪', '‘', '’', 'ফ', 'ৌ', '৮', 'ঁ', 'য়', '৩', 'ঢ', 'ঠ', '৭', ':', '।', '.', 'ড়', 'ঝ', '/', 'ঞ', '\u200c', '\x94', '"', "'", 'ঔ', 'ঈ', '\u200d', 'ঐ', '\x93', 'ঋ', '\n', '\t', '%', '”', 'ঊ', 'ৗ', '–', ';', 'œ', '_', 'ঢ়', '—', '\u200e', 'ৰ']

# %%
for i in range(0,15):
    listofuniques.pop(0)
print(listofuniques)
# Out:
# ['ঁ', 'ং', 'ঃ', 'অ', 'আ', 'ই', 'ঈ', 'উ', 'ঊ', 'ঋ', 'এ', 'ঐ', 'ও', 'ঔ', 'ক', 'খ', 'গ', 'ঘ', 'ঙ', 'চ', 'ছ', 'জ', 'ঝ', 'ঞ', 'ট', 'ঠ', 'ড', 'ঢ', 'ণ', 'ত', 'থ', 'দ', 'ধ', 'ন', 'প', 'ফ', 'ব', 'ভ', 'ম', 'য', 'র', 'ল', 'শ', 'ষ', 'স', 'হ', '়', 'া', 'ি', 'ী', 'ু', 'ূ', 'ৃ', 'ে', 'ৈ', 'ো', 'ৌ', '্', 'ৎ', 'ৗ', 'ড়', 'ঢ়', 'য়', '০', '১', '২', '৩', '৪', '৫', '৬', '৭', '৮', '৯', 'ৰ', '\u200c', '\u200d', '\u200e', '–', '—', '‘', '’', '”']

# %%
listofuniques.pop(len(listofuniques)-1)
print(listofuniques)
# Out:
# ['ঁ', 'ং', 'ঃ', 'অ', 'আ', 'ই', 'ঈ', 'উ', 'ঊ', 'ঋ', 'এ', 'ঐ', 'ও', 'ঔ', 'ক', 'খ', 'গ', 'ঘ', 'ঙ', 'চ', 'ছ', 'জ', 'ঝ', 'ঞ', 'ট', 'ঠ', 'ড', 'ঢ', 'ণ', 'ত', 'থ', 'দ', 'ধ', 'ন', 'প', 'ফ', 'ব', 'ভ', 'ম', 'য', 'র', 'ল', 'শ', 'ষ', 'স', 'হ', '়', 'া', 'ি', 'ী', 'ু', 'ূ', 'ৃ', 'ে', 'ৈ', 'ো', 'ৌ', '্', 'ৎ', 'ৗ', 'ড়', 'ঢ়', 'য়', '০', '১', '২', '৩', '৪', '৫', '৬', '৭', '৮', '৯', 'ৰ']

# %% [markdown]
# ### Transcript Parsing

# %%
import pandas as pd
slrtsv_path = 'data/asr_bengali/utt_spk_text.tsv'
df = pd.read_csv(slrtsv_path, sep='\t')
df
# Out:
#           Filename    UID                         Transcript
# 0       000020a912  16cfb            বাংলাদেশে দায়িত্ব নেবে
# 1       000039928e  976b1                এ ধরণের কার্ড নিয়ে
# 2       00005debc7  f83df                  হতে উপার্জিত অর্থ
# 3       00009e687c  9813c              হাসির বিষয় হয়েই আছে
# 4       00012843bc  7ec1c                    সার্ক দেশগুলোতে
# ...            ...    ...                                ...
# 127560  ffff6a7f59  77f82  সংস্কৃতি মন্ত্রী আবুল কালাম আযাদও
# 127561  ffff98efe5  80539                      অভিযোগ রয়েছে
# 127562  ffffc017a0  15a75             আন্তোনিও দা মাগদালেনার
# 127563  ffffe3b62d  10a9f                          মি. খানের
# 127564  fffff1c677  06e62   কাজী নজরুলের লেখা হিন্দু-মুসলমান
#
# [127565 rows x 3 columns]

# %%
import pandas as pd
df = pd.read_csv('data/openslr_bengali/openslr_transcript_ranged25-35.csv')

# %%
import data_dekhabet as dk
b = dk.banglaletters
d = dk.banglalookup
s = dk.banglashongkha

i = 0;
parsed_transcript = []
error_chars = []
for index, row in df.iterrows():
#     print('{:02d}: {}'.format(index,row[2]))
#     for c in row[2]:
#         print('{} '.format(c),end='')
#     print('')

    sentence = ''
    vectotr = []
    buffer = ''
    for c in row[2]:
        buffer += c
#         print(c, sentence, len(buffer))
        if c == ' ':
            if buffer[len(buffer)-2]=='র' or buffer[len(buffer)-2]=='়':
                sentence = sentence[:-1]
                vector = vector[:-1]
            sentence += d[b.index(c)]
            vector.append(d.index(d[b.index(c)]))
        elif c == '়':
            sentence = sentence[:-2]
            sentence += 'yo'
        elif c in dk.banglanokaars or c in s:
            sentence += d[b.index(c)]
        elif c in dk.banglakaars:
            sentence = sentence[:-1]
            sentence += d[b.index(c)]
        elif c == ' ' and buffer[len(buffer)-2]=='র':
            sentence = sentence[:-1]
            sentence += d[b.index(c)]
        else:
            try:
                sentence += d[b.index(c)]+'o'
            except:
                if c not in error_chars:
                    error_chars.append(c)
    parsed_transcript.append(sentence)
    i += 1
    if i%5000==0:
        print('{} sentences parsed.'.format(i), '=> ',parsed_transcript[i-1])
#     print(sentence,'\n')
print('{} sentences parsed.'.format(len(parsed_transcript)))
print('{} error characters faced:'.format(len(error_chars)))
print(error_chars)
# Out:
# 5000 sentences parsed. =>  esomoy chhinotaikarira
# 10000 sentences parsed. =>  fole se bhabolo
# 15000 sentences parsed. =>  nojorulo giti
# 20000 sentences parsed. =>  mondiroti porichalonayo
# 25000 sentences parsed. =>  prothomo raundo theke
# 30000 sentences parsed. =>  bichar somponner udjogo neyo
# 35000 sentences parsed. =>  amar priyo
# 40000 sentences parsed. =>  je bonojo sompodo joruri
# 45000 sentences parsed. =>  95 sale tar bhai
# 50000 sentences parsed. =>  chole jano tino
# 55000 sentences parsed. =>  ar amora prokrto premikora chirodinoi bonchito theke gelamo
# 60000 sentences parsed. =>  jara chakori khujochheno tader jonjo agami soptahota khuboi shubho
# 65000 sentences parsed. =>  paikari bikreta
# 70000 sentences parsed. =>  sobar samonei ghote emono ghotona
# 75000 sentences parsed. =>  sokolei loker chitto nibishto
# 80000 sentences parsed. =>  startoape seto kore
# 85000 sentences parsed. =>  jonogono dirghokalo dhorei
# 90000 sentences parsed. =>  uttora theke motijhilo rute
# 95000 sentences parsed. =>  osubidhateo poyote hoyo
# 100000 sentences parsed. =>  jaha tahara
# 105000 sentences parsed. =>  bjobosabanijjer obostha
# 110000 sentences parsed. =>  ar ei joriper poro
# 115000 sentences parsed. =>  edike pulisher bondukojuddho niye
# 120000 sentences parsed. =>  sesobo bostuteo
# 125000 sentences parsed. =>  golo kore
# 127565 sentences parsed.
# 74 error characters faced:
# ['ঃ', '-', '‘', '’', ',', 'ঁ', ':', '।', '.', '/', '\u200c', '\x94', '"', "'", 'v', 'b', 's', '\u200d', '\x93', '!', '2', '0', '1', '4', 'f', 'o', 't', 'a', 'l', 'w', 'r', 'd', 'c', 'u', 'p', 'n', 'g', '\n', '5', '8', 'e', '9', '\t', '3', '6', '7', '%', 'i', 'B', 'z', '…', '“', '”', 'L', 'm', 'T', 'h', 'x', '?', 'y', '–', ';', 'j', 'œ', '_', 'F', '—', '\u200e', 'O', 'H', 'k', 'D', 'K', 'ৰ']

# %%
df = df.assign(Dekhascript = parsed_transcript)
df
# Out:
#           Filename    UID                         Transcript  \
# 0       000020a912  16cfb            বাংলাদেশে দায়িত্ব নেবে
# 1       000039928e  976b1                এ ধরণের কার্ড নিয়ে
# 2       00005debc7  f83df                  হতে উপার্জিত অর্থ
# 3       00009e687c  9813c              হাসির বিষয় হয়েই আছে
# 4       00012843bc  7ec1c                    সার্ক দেশগুলোতে
# ...            ...    ...                                ...
# 127560  ffff6a7f59  77f82  সংস্কৃতি মন্ত্রী আবুল কালাম আযাদও
# 127561  ffff98efe5  80539                      অভিযোগ রয়েছে
# 127562  ffffc017a0  15a75             আন্তোনিও দা মাগদালেনার
# 127563  ffffe3b62d  10a9f                          মি. খানের
# 127564  fffff1c677  06e62   কাজী নজরুলের লেখা হিন্দু-মুসলমান
#
#                                  Dekhascript
# 0                   bangladeshe dayitbo nebe
# 1                      e dhoroner kardo niye
# 2                        hote uparjito ortho
# 3                   hasir bishoy hoyei achhe
# 4                          sarko deshogulote
# ...                                      ...
# 127560  songskrti montri abulo kalamo ajadoo
# 127561                     obhijogo royechhe
# 127562               antonio da magodalenaro
# 127563                            mi khanero
# 127564  kaji nojoruler lekha hindumusolomano
#
# [127565 rows x 4 columns]

# %%
df.to_csv('data/asr_bengali/openslr_transcript.csv')

# %% [markdown]
# ### Audio file and Time Range management

# %%
import numpy as np
# import pyaudio
import audio_metadata as am
import os
from os.path import isfile, join
import matplotlib.pyplot as plt
import pandas as pd

# %%
data_path = 'data/asr_bengali/data/'
# audiofiles = [join(data_path,f) for f in os.listdir(data_path) if isfile(join(data_path, f))]
# audiofiles

listOfFiles = list()
for (dirpath, dirnames, filenames) in os.walk(data_path):
    listOfFiles += [os.path.join(dirpath, file) for file in filenames if file.endswith('.flac')]

# %%
print(len(listOfFiles))
print(listOfFiles[0:5])
print(am.load(listOfFiles[0]).streaminfo.duration)
# Out:
# 218703
# ['data/asr_bengali/data/00\\000020a912.flac', 'data/asr_bengali/data/00\\000039928e.flac', 'data/asr_bengali/data/00\\00005debc7.flac', 'data/asr_bengali/data/00\\00009e687c.flac', 'data/asr_bengali/data/00\\00012843bc.flac']
# 3.3

# %%
df = pd.read_csv('data/asr_bengali/openslr_transcript.csv')
df
# Out:
#         Unnamed: 0    Filename    UID                         Transcript  \
# 0                0  000020a912  16cfb            বাংলাদেশে দায়িত্ব নেবে
# 1                1  000039928e  976b1                এ ধরণের কার্ড নিয়ে
# 2                2  00005debc7  f83df                  হতে উপার্জিত অর্থ
# 3                3  00009e687c  9813c              হাসির বিষয় হয়েই আছে
# 4                4  00012843bc  7ec1c                    সার্ক দেশগুলোতে
# ...            ...         ...    ...                                ...
# 127560      127560  ffff6a7f59  77f82  সংস্কৃতি মন্ত্রী আবুল কালাম আযাদও
# 127561      127561  ffff98efe5  80539                      অভিযোগ রয়েছে
# 127562      127562  ffffc017a0  15a75             আন্তোনিও দা মাগদালেনার
# 127563      127563  ffffe3b62d  10a9f                          মি. খানের
# 127564      127564  fffff1c677  06e62   কাজী নজরুলের লেখা হিন্দু-মুসলমান
#
#                                  Dekhascript
# 0                   bangladeshe dayitbo nebe
# 1                      e dhoroner kardo niye
# 2                        hote uparjito ortho
# 3                   hasir bishoy hoyei achhe
# 4                          sarko deshogulote
# ...                                      ...
# 127560  songskrti montri abulo kalamo ajadoo
# 127561                     obhijogo royechhe
# 127562               antonio da magodalenaro
# 127563                            mi khanero
# 127564  kaji nojoruler lekha hindumusolomano
#
# [127565 rows x 5 columns]

# %% [markdown]
# ## ProgressBar Function

# %%
import time, sys
from IPython.display import clear_output

def update_progress(progress, endprogress):
    bar_length = 40
    if isinstance(progress, int):
        progress = float(progress)
    if not isinstance(progress, float):
        progress = 0
    if progress < 0:
        progress = 0
    if progress >= 1:
        progress = 1

    block = int(round(bar_length * progress))

    clear_output(wait = True)
    text = "Progress: [{0}] {1:.1f}%".format( "#" * block + "-" * (bar_length - block), progress*100)
    print(text, str(int(round(progress*endprogress)))+'/'+str(endprogress))

# %%
i = 0
durationlist = []

for index, row in df.iterrows():
    fl = 'data/asr_bengali/data/{}/{}.flac'.format(row['Filename'][0:2], row['Filename'])
    durationlist.append(am.load(fl).streaminfo.duration)
    update_progress(index / len(df))

update_progress(1)
len(durationlist)
# Out:
# Progress: [####################] 100.0%
# 127565

# %%
df = df.assign(DurationSec = durationlist)
df
# Out:
#         Unnamed: 0    Filename    UID                         Transcript  \
# 0                0  000020a912  16cfb            বাংলাদেশে দায়িত্ব নেবে
# 1                1  000039928e  976b1                এ ধরণের কার্ড নিয়ে
# 2                2  00005debc7  f83df                  হতে উপার্জিত অর্থ
# 3                3  00009e687c  9813c              হাসির বিষয় হয়েই আছে
# 4                4  00012843bc  7ec1c                    সার্ক দেশগুলোতে
# ...            ...         ...    ...                                ...
# 127560      127560  ffff6a7f59  77f82  সংস্কৃতি মন্ত্রী আবুল কালাম আযাদও
# 127561      127561  ffff98efe5  80539                      অভিযোগ রয়েছে
# 127562      127562  ffffc017a0  15a75             আন্তোনিও দা মাগদালেনার
# 127563      127563  ffffe3b62d  10a9f                          মি. খানের
# 127564      127564  fffff1c677  06e62   কাজী নজরুলের লেখা হিন্দু-মুসলমান
#
#                                  Dekhascript  DurationSec
# 0                   bangladeshe dayitbo nebe          3.3
# 1                      e dhoroner kardo niye          2.4
# 2                        hote uparjito ortho          3.2
# 3                   hasir bishoy hoyei achhe          2.9
# 4                          sarko deshogulote          3.3
# ...                                      ...          ...
# 127560  songskrti montri abulo kalamo ajadoo          4.6
# 127561                     obhijogo royechhe          2.8
# 127562               antonio da magodalenaro          9.9
# 127563                            mi khanero          2.0
# 127564  kaji nojoruler lekha hindumusolomano          3.4
#
# [127565 rows x 6 columns]

# %%
df.to_csv('data/asr_bengali/openslr_transcript.csv', index=False)

# %%
df = pd.read_csv('data/asr_bengali/openslr_transcript.csv')

# %%
df = df.drop(['Unnamed: 0'], axis = 1)
df
# Out:
#           Filename    UID                         Transcript  \
# 0       000020a912  16cfb            বাংলাদেশে দায়িত্ব নেবে
# 1       000039928e  976b1                এ ধরণের কার্ড নিয়ে
# 2       00005debc7  f83df                  হতে উপার্জিত অর্থ
# 3       00009e687c  9813c              হাসির বিষয় হয়েই আছে
# 4       00012843bc  7ec1c                    সার্ক দেশগুলোতে
# ...            ...    ...                                ...
# 127560  ffff6a7f59  77f82  সংস্কৃতি মন্ত্রী আবুল কালাম আযাদও
# 127561  ffff98efe5  80539                      অভিযোগ রয়েছে
# 127562  ffffc017a0  15a75             আন্তোনিও দা মাগদালেনার
# 127563  ffffe3b62d  10a9f                          মি. খানের
# 127564  fffff1c677  06e62   কাজী নজরুলের লেখা হিন্দু-মুসলমান
#
#                                  Dekhascript  DurationSec
# 0                   bangladeshe dayitbo nebe          3.3
# 1                      e dhoroner kardo niye          2.4
# 2                        hote uparjito ortho          3.2
# 3                   hasir bishoy hoyei achhe          2.9
# 4                          sarko deshogulote          3.3
# ...                                      ...          ...
# 127560  songskrti montri abulo kalamo ajadoo          4.6
# 127561                     obhijogo royechhe          2.8
# 127562               antonio da magodalenaro          9.9
# 127563                            mi khanero          2.0
# 127564  kaji nojoruler lekha hindumusolomano          3.4
#
# [127565 rows x 5 columns]

# %%
df.to_csv('data/asr_bengali/openslr_transcript.csv', index=False)

# %%
df = pd.read_csv('data/asr_bengali/openslr_transcript.csv')

# %%
print(df['DurationSec'].describe())
listodur = df['DurationSec'].tolist()
listodur.sort()
# Out:
# count    127565.000000
# mean          3.551357
# std           1.192111
# min           0.100000
# 25%           2.800000
# 50%           3.300000
# 75%           4.000000
# max          26.100000
# Name: DurationSec, dtype: float64

# %%
plt.figure(figsize=(16,8))
from matplotlib import pyplot as plt

data = listodur
max_x = 10
bins = np.arange(0, max_x, 0.1) # fixed bin size

plt.xlim([0, max_x])
plt.hist(data, bins=bins, alpha=0.5)
plt.title('Audio Playback Time Distribution')
plt.xticks(np.arange(0, max_x, 1.0))
plt.xlabel('Playback Time')
plt.ylabel('File Count')

plt.show()

# %%
listodurt = []
for i in listodur:
    if i>=2.5 and i<=3.5:
        listodurt.append(i)
        
print(len(listodurt))
print('this is {:.1f}% the original dataset'.format(len(listodurt)/len(listodur)*100))
# Out:
# 61133
# this is 47.9% the original dataset

# %% [markdown]
# ### OpenSLR Spectrogram Processing

# %%
import pandas as pd
import data_wav2specto as w2s
import progressbar as progbar

df = pd.read_csv('data/asr_bengali/openslr_transcript.csv')
df.head()
# Out:
#      Filename    UID               Transcript               Dekhascript  \
# 0  000020a912  16cfb  বাংলাদেশে দায়িত্ব নেবে  bangladeshe dayitbo nebe
# 1  000039928e  976b1      এ ধরণের কার্ড নিয়ে     e dhoroner kardo niye
# 2  00005debc7  f83df        হতে উপার্জিত অর্থ       hote uparjito ortho
# 3  00009e687c  9813c    হাসির বিষয় হয়েই আছে  hasir bishoy hoyei achhe
# 4  00012843bc  7ec1c          সার্ক দেশগুলোতে         sarko deshogulote
#
#    DurationSec
# 0          3.3
# 1          2.4
# 2          3.2
# 3          2.9
# 4          3.3

# %%
### MEMORY ERROR IF USED IN JUPYTER ###

# durationrange = [2.5, 3.5]
# data_dir = 'data/asr_bengali/data/'
# count = 0
# l = len(df)
# for i, row in df.iterrows():
#     progbar.update_progress(i/l, l)
#     wavfile = data_dir + '{}/{}.flac'.format(row['Filename'][0:2], row['Filename'])
#     if row['DurationSec']>=durationrange[0] and row['DurationSec']>=durationrange[1]:
# #         w2s.graph_spectrogram(wavfile)
#         w2s.graph_melcepstrum(wavfile)
#         count += 1
# progbar.update_progress(1,l)
# print(count, 'mel spectrograms calculated')

# %%
import pandas as pd

df = pd.read_csv('data/asr_bengali/openslr_transcript.csv')
df
# Out:
#           Filename    UID                         Transcript  \
# 0       000020a912  16cfb            বাংলাদেশে দায়িত্ব নেবে
# 1       000039928e  976b1                এ ধরণের কার্ড নিয়ে
# 2       00005debc7  f83df                  হতে উপার্জিত অর্থ
# 3       00009e687c  9813c              হাসির বিষয় হয়েই আছে
# 4       00012843bc  7ec1c                    সার্ক দেশগুলোতে
# ...            ...    ...                                ...
# 127560  ffff6a7f59  77f82  সংস্কৃতি মন্ত্রী আবুল কালাম আযাদও
# 127561  ffff98efe5  80539                      অভিযোগ রয়েছে
# 127562  ffffc017a0  15a75             আন্তোনিও দা মাগদালেনার
# 127563  ffffe3b62d  10a9f                          মি. খানের
# 127564  fffff1c677  06e62   কাজী নজরুলের লেখা হিন্দু-মুসলমান
#
#                                  Dekhascript  DurationSec
# 0                   bangladeshe dayitbo nebe          3.3
# 1                      e dhoroner kardo niye          2.4
# 2                        hote uparjito ortho          3.2
# 3                   hasir bishoy hoyei achhe          2.9
# 4                          sarko deshogulote          3.3
# ...                                      ...          ...
# 127560  songskrti montri abulo kalamo ajadoo          4.6
# 127561                     obhijogo royechhe          2.8
# 127562               antonio da magodalenaro          9.9
# 127563                            mi khanero          2.0
# 127564  kaji nojoruler lekha hindumusolomano          3.4
#
# [127565 rows x 5 columns]

# %%
dfr = df[(df['DurationSec']>=2.5) & (df['DurationSec']<=3.5)]
dfr.to_csv('data/openslr_transcript_ranged2.csv', index=False)
dfr
# Out:
#           Filename    UID                        Transcript  \
# 0       000020a912  16cfb           বাংলাদেশে দায়িত্ব নেবে
# 2       00005debc7  f83df                 হতে উপার্জিত অর্থ
# 3       00009e687c  9813c             হাসির বিষয় হয়েই আছে
# 4       00012843bc  7ec1c                   সার্ক দেশগুলোতে
# 5       00012880b1  e43d4                 সহজেই যাওয়া যায়
# ...            ...    ...                               ...
# 127555  fffcbc5991  80be1                       মাছ টাছ ধরে
# 127556  fffda05c98  9fa90                   কঠিন হয়ে পড়বে
# 127559  fffedef4e5  80be1               তাঁহার আত্মার সঙ্গে
# 127561  ffff98efe5  80539                     অভিযোগ রয়েছে
# 127564  fffff1c677  06e62  কাজী নজরুলের লেখা হিন্দু-মুসলমান
#
#                                  Dekhascript  DurationSec
# 0                   bangladeshe dayitbo nebe          3.3
# 2                        hote uparjito ortho          3.2
# 3                   hasir bishoy hoyei achhe          2.9
# 4                          sarko deshogulote          3.3
# 5                         sohojei jaoya jayo          2.7
# ...                                      ...          ...
# 127555                   machho tachho dhore          3.2
# 127556                   kothino hoye poyobe          3.3
# 127559                    tahar atmar songge          3.5
# 127561                     obhijogo royechhe          2.8
# 127564  kaji nojoruler lekha hindumusolomano          3.4
#
# [61133 rows x 5 columns]

# %%
import pandas as pd
import data_dekhabet as dkb
import progressbar as prgs
csvf = 'data/openslr_bengali/openslr_transcript_ranged.csv'
dfr = pd.read_csv(csvf)

# %%
vector = []
l = len(dfr)
prgs.printProgressBar(0,l)
for index, row in dfr.iterrows():
    vc = []
    for c in str(row['Dekhascript']):
        vc.append(dkb.tokenlookup2.index(c))
    vector.append(vc)
    prgs.printProgressBar(index,l)
dfr = dfr.assign(Vector = vector)
dfr
# Out:
#  |#######################################-| 100.0%
#          Filename    UID                        Transcript  \
# 0      000020a912  16cfb           বাংলাদেশে দায়িত্ব নেবে
# 1      00005debc7  f83df                 হতে উপার্জিত অর্থ
# 2      00009e687c  9813c             হাসির বিষয় হয়েই আছে
# 3      00012843bc  7ec1c                   সার্ক দেশগুলোতে
# 4      00012880b1  e43d4                 সহজেই যাওয়া যায়
# ...           ...    ...                               ...
# 61128  fffcbc5991  80be1                       মাছ টাছ ধরে
# 61129  fffda05c98  9fa90                   কঠিন হয়ে পড়বে
# 61130  fffedef4e5  80be1               তাঁহার আত্মার সঙ্গে
# 61131  ffff98efe5  80539                     অভিযোগ রয়েছে
# 61132  fffff1c677  06e62  কাজী নজরুলের লেখা হিন্দু-মুসলমান
#
#                                 Dekhascript  DurationSec  \
# 0                  bangladeshe dayitbo nebe          3.3
# 1                       hote uparjito ortho          3.2
# 2                  hasir bishoy hoyei achhe          2.9
# 3                         sarko deshogulote          3.3
# 4                        sohojei jaoya jayo          2.7
# ...                                     ...          ...
# 61128                   machho tachho dhore          3.2
# 61129                   kothino hoye poyobe          3.3
# 61130                    tahar atmar songge          3.5
# 61131                     obhijogo royechhe          2.8
# 61132  kaji nojoruler lekha hindumusolomano          3.4
#
#                                                   Vector
# 0      [10, 1, 17, 8, 15, 1, 19, 2, 12, 11, 2, 0, 19,...
# 1      [11, 4, 13, 2, 0, 5, 9, 1, 18, 14, 3, 13, 4, 0...
# 2      [11, 1, 12, 3, 18, 0, 10, 3, 12, 11, 4, 21, 0,...
# 3      [12, 1, 18, 20, 4, 0, 19, 2, 12, 11, 4, 8, 5, ...
# 4      [12, 4, 11, 4, 14, 2, 3, 0, 14, 1, 4, 21, 1, 0...
# ...                                                  ...
# 61128  [16, 1, 7, 11, 11, 4, 0, 13, 1, 7, 11, 11, 4, ...
# 61129  [20, 4, 13, 11, 3, 17, 4, 0, 11, 4, 21, 2, 0, ...
# 61130  [13, 1, 11, 1, 18, 0, 1, 13, 16, 1, 18, 0, 12,...
# 61131  [4, 10, 11, 3, 14, 4, 8, 4, 0, 18, 4, 21, 2, 7...
# 61132  [20, 1, 14, 3, 0, 17, 4, 14, 4, 18, 5, 15, 2, ...
#
# [61133 rows x 6 columns]

# %%
dfr.to_csv(csvf, index=False)
