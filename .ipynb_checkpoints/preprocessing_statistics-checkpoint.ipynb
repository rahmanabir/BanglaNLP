# %% [markdown]
# ## Metadata Access

# %%
import numpy as np
import pyaudio
import audio_metadata
from os import listdir
from os.path import isfile, join
import matplotlib.pyplot as plt

data_path = 'data/crblp/wav/'
audiofiles = [join(data_path,f) for f in listdir(data_path) if isfile(join(data_path, f))]

# %%
print(audiofiles[0])
print(len(audiofiles))

# %%
metadata = audio_metadata.load(audiofiles[0])
print(metadata, '\n')
print(type(metadata.streaminfo.duration))
print(metadata.streaminfo.duration,'in seconds')

# %%
listofdurations = []
countofbadwaves = 0
for wavfile in audiofiles:
    try:
        meta = audio_metadata.load(wavfile)
        listofdurations.append(meta.streaminfo.duration)
    except:
        countofbadwaves += 1
        print(wavfile,'has bad header')

print('Length of Wavfile Durations List:',len(listofdurations))
print('No. of Bad header Wavfiles:',countofbadwaves)

# %% [markdown]
# ## Duration Stats

# %%
listofdurations.sort()
print('Audio Time Stats')
print('----------------')
print('Size of Array:',len(listofdurations))
print('Maximum:',round(max(listofdurations),2))
print('Minimum:',round(min(listofdurations),2))
print('Mean',round(sum(listofdurations)/len(listofdurations),2))
print('Median:',round(listofdurations[int(len(listofdurations)/2)],2))
print('LoQuart:',round(listofdurations[int(len(listofdurations)/2) - int(len(listofdurations)/4)],2))
print('UpQuart:',round(listofdurations[int(len(listofdurations)/2) + int(len(listofdurations)/4)],2))

# %%
plt.figure(figsize=(16,8))
from matplotlib import pyplot as plt

# data = np.random.normal(0, 20, 1000) 
data = listofdurations

# fixed bin size
bins = np.arange(0, 20, 0.1) # fixed bin size

plt.xlim([0, 20])

plt.hist(data, bins=bins, alpha=0.5)
plt.title('Audio Playback Time Distribution')
plt.xticks(np.arange(0, 20, 1.0))
plt.xlabel('Playback Time')
plt.ylabel('File Count')

plt.show()

# %% [markdown]
# ## File Ranging

# %%
validtimes = []
for f in audiofiles:
    try:
        t = audio_metadata.load(f).streaminfo.duration
        if t>=1 and t<=2:
            validtimes.append(f)
    except:
        print('Bad Header:',f)
        
print(len(validtimes))
print(validtimes[0])
print(validtimes[len(validtimes)-1])

# %%
file = open('data_RangedAudiofileList_1to2.txt','w') 
for f in validtimes:
    file.write(f)
    file.write('\n')
file.close()

# %% [markdown]
# ## Character Frequency Distribution

# %%
import csv
import data_dekhabet as dkb
lookup = dkb.tokenlookup
leng = len(lookup)
countlook = [0]*leng


print(lookup)
print(leng)
print(countlook)

# %%
csvf = 'dekhabet_dataLabelsRanged.csv'
counter = []
with open(csvf, 'r') as csvFile:
    reader = csv.reader(csvFile)
    for row in reader:
        ctext = []
        text = row[4]
        text = text.strip("'-!$[]")
        text = text.split(',')
        i=0
        if 'Tokens' in text:
            pass
        else:
            for t in range(0,len(text)):
                i = int(text[t])
                counter.append(lookup[i])
csvFile.close()

# %%
import pandas
from collections import Counter
# a = ['a', 'a', 'a', 'a', 'b', 'b', 'c', 'c', 'c', 'd', 'e', 'e', 'e', 'e', 'e']
letter_counts = Counter(counter)
print(letter_counts)
df = pandas.DataFrame.from_dict(letter_counts, orient='index')
df.plot(kind='bar',figsize=(8,6))

# %% [markdown]
# ## Google OpenSLR Stats

# %%
import csv
slrtsv_path = 'data/openslr_transcript.tsv'
with open(slrtsv_path, 'r') as csvFile:
    reader = csv.reader(csvFile, delimiter='\t')
    count = 0
    for row in reader:
        count+=1
csvFile.close()
print(c)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-40-538f9020bce7> in <module>
#       4     reader = csv.reader(csvFile, delimiter='\t')
#       5     count = 0
# ----> 6     for row in reader:
#       7         count+=1
#       8 csvFile.close()
#
# Error: field larger than field limit (131072)

# %%
import pandas as pd
slrtsv_path = 'data/openslr_transcript.tsv'
df = pd.read_csv(slrtsv_path, sep='\t')
df
# Out:
#           filename randuid                        banglatrans
# 0       000020a912   16cfb            বাংলাদেশে দায়িত্ব নেবে
# 1       000039928e   976b1                এ ধরণের কার্ড নিয়ে
# 2       00005debc7   f83df                  হতে উপার্জিত অর্থ
# 3       00009e687c   9813c              হাসির বিষয় হয়েই আছে
# 4       00012843bc   7ec1c                    সার্ক দেশগুলোতে
# ...            ...     ...                                ...
# 127560  ffff6a7f59   77f82  সংস্কৃতি মন্ত্রী আবুল কালাম আযাদও
# 127561  ffff98efe5   80539                      অভিযোগ রয়েছে
# 127562  ffffc017a0   15a75             আন্তোনিও দা মাগদালেনার
# 127563  ffffe3b62d   10a9f                          মি. খানের
# 127564  fffff1c677   06e62   কাজী নজরুলের লেখা হিন্দু-মুসলমান
#
# [127565 rows x 3 columns]

# %%
print(df.head())
# Out:
#      filename randuid              banglatrans
# 0  000020a912   16cfb  বাংলাদেশে দায়িত্ব নেবে
# 1  000039928e   976b1      এ ধরণের কার্ড নিয়ে
# 2  00005debc7   f83df        হতে উপার্জিত অর্থ
# 3  00009e687c   9813c    হাসির বিষয় হয়েই আছে
# 4  00012843bc   7ec1c          সার্ক দেশগুলোতে

# %% [markdown]
# ### Find unique characters

# %%
listofuniques = []
engletters = 'qwertyuiopasdfghjklzxcvbnmQWERTYUIOPASDFGHJKLZXCVBNM1234567890-…,!?“'
for index, row in df.iterrows():
    if index%10000==0:
        print(index,listofuniques)
    for c in row[2]:
        if c not in engletters and len(c) <= 1:
            if c not in listofuniques:
                listofuniques.append(c)
listofuniques.sort()
print(listofuniques, len(listofuniques))
# Out:
# 0 []
# 10000 ['এ', ' ', 'ধ', 'র', 'ণ', 'ে', 'ক', 'া', '্', 'ড', 'ন', 'ি', 'য', '়', 'হ', 'ত', 'উ', 'প', 'জ', 'অ', 'থ', 'স', 'ব', 'ষ', 'ই', 'আ', 'ছ', 'দ', 'শ', 'গ', 'ু', 'ল', 'ো', 'ও', 'ভ', 'ী', 'ট', 'ূ', 'ম', 'ৈ', 'ৃ', 'ঙ', 'খ', 'ঃ', '১', '৯', '৬', '০', '২', 'ং', 'চ', 'ঘ', 'ৎ', '৫', '৪', '‘', '’', 'ফ', 'ৌ', '৮', 'ঁ', 'য়', '৩', 'ঢ', 'ঠ', '৭', ':', '।', '.', 'ড়', 'ঝ', '/', 'ঞ', '\u200c', '\x94', '"', "'", 'ঔ', 'ঈ', '\u200d', 'ঐ', '\x93', 'ঋ', '\n', '\t', '%', '”', 'ঊ']
# 20000 ['এ', ' ', 'ধ', 'র', 'ণ', 'ে', 'ক', 'া', '্', 'ড', 'ন', 'ি', 'য', '়', 'হ', 'ত', 'উ', 'প', 'জ', 'অ', 'থ', 'স', 'ব', 'ষ', 'ই', 'আ', 'ছ', 'দ', 'শ', 'গ', 'ু', 'ল', 'ো', 'ও', 'ভ', 'ী', 'ট', 'ূ', 'ম', 'ৈ', 'ৃ', 'ঙ', 'খ', 'ঃ', '১', '৯', '৬', '০', '২', 'ং', 'চ', 'ঘ', 'ৎ', '৫', '৪', '‘', '’', 'ফ', 'ৌ', '৮', 'ঁ', 'য়', '৩', 'ঢ', 'ঠ', '৭', ':', '।', '.', 'ড়', 'ঝ', '/', 'ঞ', '\u200c', '\x94', '"', "'", 'ঔ', 'ঈ', '\u200d', 'ঐ', '\x93', 'ঋ', '\n', '\t', '%', '”', 'ঊ', 'ৗ', '–', ';']
# 30000 ['এ', ' ', 'ধ', 'র', 'ণ', 'ে', 'ক', 'া', '্', 'ড', 'ন', 'ি', 'য', '়', 'হ', 'ত', 'উ', 'প', 'জ', 'অ', 'থ', 'স', 'ব', 'ষ', 'ই', 'আ', 'ছ', 'দ', 'শ', 'গ', 'ু', 'ল', 'ো', 'ও', 'ভ', 'ী', 'ট', 'ূ', 'ম', 'ৈ', 'ৃ', 'ঙ', 'খ', 'ঃ', '১', '৯', '৬', '০', '২', 'ং', 'চ', 'ঘ', 'ৎ', '৫', '৪', '‘', '’', 'ফ', 'ৌ', '৮', 'ঁ', 'য়', '৩', 'ঢ', 'ঠ', '৭', ':', '।', '.', 'ড়', 'ঝ', '/', 'ঞ', '\u200c', '\x94', '"', "'", 'ঔ', 'ঈ', '\u200d', 'ঐ', '\x93', 'ঋ', '\n', '\t', '%', '”', 'ঊ', 'ৗ', '–', ';', 'œ']
# 40000 ['এ', ' ', 'ধ', 'র', 'ণ', 'ে', 'ক', 'া', '্', 'ড', 'ন', 'ি', 'য', '়', 'হ', 'ত', 'উ', 'প', 'জ', 'অ', 'থ', 'স', 'ব', 'ষ', 'ই', 'আ', 'ছ', 'দ', 'শ', 'গ', 'ু', 'ল', 'ো', 'ও', 'ভ', 'ী', 'ট', 'ূ', 'ম', 'ৈ', 'ৃ', 'ঙ', 'খ', 'ঃ', '১', '৯', '৬', '০', '২', 'ং', 'চ', 'ঘ', 'ৎ', '৫', '৪', '‘', '’', 'ফ', 'ৌ', '৮', 'ঁ', 'য়', '৩', 'ঢ', 'ঠ', '৭', ':', '।', '.', 'ড়', 'ঝ', '/', 'ঞ', '\u200c', '\x94', '"', "'", 'ঔ', 'ঈ', '\u200d', 'ঐ', '\x93', 'ঋ', '\n', '\t', '%', '”', 'ঊ', 'ৗ', '–', ';', 'œ']
# 50000 ['এ', ' ', 'ধ', 'র', 'ণ', 'ে', 'ক', 'া', '্', 'ড', 'ন', 'ি', 'য', '়', 'হ', 'ত', 'উ', 'প', 'জ', 'অ', 'থ', 'স', 'ব', 'ষ', 'ই', 'আ', 'ছ', 'দ', 'শ', 'গ', 'ু', 'ল', 'ো', 'ও', 'ভ', 'ী', 'ট', 'ূ', 'ম', 'ৈ', 'ৃ', 'ঙ', 'খ', 'ঃ', '১', '৯', '৬', '০', '২', 'ং', 'চ', 'ঘ', 'ৎ', '৫', '৪', '‘', '’', 'ফ', 'ৌ', '৮', 'ঁ', 'য়', '৩', 'ঢ', 'ঠ', '৭', ':', '।', '.', 'ড়', 'ঝ', '/', 'ঞ', '\u200c', '\x94', '"', "'", 'ঔ', 'ঈ', '\u200d', 'ঐ', '\x93', 'ঋ', '\n', '\t', '%', '”', 'ঊ', 'ৗ', '–', ';', 'œ', '_']
# 60000 ['এ', ' ', 'ধ', 'র', 'ণ', 'ে', 'ক', 'া', '্', 'ড', 'ন', 'ি', 'য', '়', 'হ', 'ত', 'উ', 'প', 'জ', 'অ', 'থ', 'স', 'ব', 'ষ', 'ই', 'আ', 'ছ', 'দ', 'শ', 'গ', 'ু', 'ল', 'ো', 'ও', 'ভ', 'ী', 'ট', 'ূ', 'ম', 'ৈ', 'ৃ', 'ঙ', 'খ', 'ঃ', '১', '৯', '৬', '০', '২', 'ং', 'চ', 'ঘ', 'ৎ', '৫', '৪', '‘', '’', 'ফ', 'ৌ', '৮', 'ঁ', 'য়', '৩', 'ঢ', 'ঠ', '৭', ':', '।', '.', 'ড়', 'ঝ', '/', 'ঞ', '\u200c', '\x94', '"', "'", 'ঔ', 'ঈ', '\u200d', 'ঐ', '\x93', 'ঋ', '\n', '\t', '%', '”', 'ঊ', 'ৗ', '–', ';', 'œ', '_']
# 70000 ['এ', ' ', 'ধ', 'র', 'ণ', 'ে', 'ক', 'া', '্', 'ড', 'ন', 'ি', 'য', '়', 'হ', 'ত', 'উ', 'প', 'জ', 'অ', 'থ', 'স', 'ব', 'ষ', 'ই', 'আ', 'ছ', 'দ', 'শ', 'গ', 'ু', 'ল', 'ো', 'ও', 'ভ', 'ী', 'ট', 'ূ', 'ম', 'ৈ', 'ৃ', 'ঙ', 'খ', 'ঃ', '১', '৯', '৬', '০', '২', 'ং', 'চ', 'ঘ', 'ৎ', '৫', '৪', '‘', '’', 'ফ', 'ৌ', '৮', 'ঁ', 'য়', '৩', 'ঢ', 'ঠ', '৭', ':', '।', '.', 'ড়', 'ঝ', '/', 'ঞ', '\u200c', '\x94', '"', "'", 'ঔ', 'ঈ', '\u200d', 'ঐ', '\x93', 'ঋ', '\n', '\t', '%', '”', 'ঊ', 'ৗ', '–', ';', 'œ', '_', 'ঢ়']
# 80000 ['এ', ' ', 'ধ', 'র', 'ণ', 'ে', 'ক', 'া', '্', 'ড', 'ন', 'ি', 'য', '়', 'হ', 'ত', 'উ', 'প', 'জ', 'অ', 'থ', 'স', 'ব', 'ষ', 'ই', 'আ', 'ছ', 'দ', 'শ', 'গ', 'ু', 'ল', 'ো', 'ও', 'ভ', 'ী', 'ট', 'ূ', 'ম', 'ৈ', 'ৃ', 'ঙ', 'খ', 'ঃ', '১', '৯', '৬', '০', '২', 'ং', 'চ', 'ঘ', 'ৎ', '৫', '৪', '‘', '’', 'ফ', 'ৌ', '৮', 'ঁ', 'য়', '৩', 'ঢ', 'ঠ', '৭', ':', '।', '.', 'ড়', 'ঝ', '/', 'ঞ', '\u200c', '\x94', '"', "'", 'ঔ', 'ঈ', '\u200d', 'ঐ', '\x93', 'ঋ', '\n', '\t', '%', '”', 'ঊ', 'ৗ', '–', ';', 'œ', '_', 'ঢ়', '—', '\u200e']
# 90000 ['এ', ' ', 'ধ', 'র', 'ণ', 'ে', 'ক', 'া', '্', 'ড', 'ন', 'ি', 'য', '়', 'হ', 'ত', 'উ', 'প', 'জ', 'অ', 'থ', 'স', 'ব', 'ষ', 'ই', 'আ', 'ছ', 'দ', 'শ', 'গ', 'ু', 'ল', 'ো', 'ও', 'ভ', 'ী', 'ট', 'ূ', 'ম', 'ৈ', 'ৃ', 'ঙ', 'খ', 'ঃ', '১', '৯', '৬', '০', '২', 'ং', 'চ', 'ঘ', 'ৎ', '৫', '৪', '‘', '’', 'ফ', 'ৌ', '৮', 'ঁ', 'য়', '৩', 'ঢ', 'ঠ', '৭', ':', '।', '.', 'ড়', 'ঝ', '/', 'ঞ', '\u200c', '\x94', '"', "'", 'ঔ', 'ঈ', '\u200d', 'ঐ', '\x93', 'ঋ', '\n', '\t', '%', '”', 'ঊ', 'ৗ', '–', ';', 'œ', '_', 'ঢ়', '—', '\u200e']
# 100000 ['এ', ' ', 'ধ', 'র', 'ণ', 'ে', 'ক', 'া', '্', 'ড', 'ন', 'ি', 'য', '়', 'হ', 'ত', 'উ', 'প', 'জ', 'অ', 'থ', 'স', 'ব', 'ষ', 'ই', 'আ', 'ছ', 'দ', 'শ', 'গ', 'ু', 'ল', 'ো', 'ও', 'ভ', 'ী', 'ট', 'ূ', 'ম', 'ৈ', 'ৃ', 'ঙ', 'খ', 'ঃ', '১', '৯', '৬', '০', '২', 'ং', 'চ', 'ঘ', 'ৎ', '৫', '৪', '‘', '’', 'ফ', 'ৌ', '৮', 'ঁ', 'য়', '৩', 'ঢ', 'ঠ', '৭', ':', '।', '.', 'ড়', 'ঝ', '/', 'ঞ', '\u200c', '\x94', '"', "'", 'ঔ', 'ঈ', '\u200d', 'ঐ', '\x93', 'ঋ', '\n', '\t', '%', '”', 'ঊ', 'ৗ', '–', ';', 'œ', '_', 'ঢ়', '—', '\u200e']
# 110000 ['এ', ' ', 'ধ', 'র', 'ণ', 'ে', 'ক', 'া', '্', 'ড', 'ন', 'ি', 'য', '়', 'হ', 'ত', 'উ', 'প', 'জ', 'অ', 'থ', 'স', 'ব', 'ষ', 'ই', 'আ', 'ছ', 'দ', 'শ', 'গ', 'ু', 'ল', 'ো', 'ও', 'ভ', 'ী', 'ট', 'ূ', 'ম', 'ৈ', 'ৃ', 'ঙ', 'খ', 'ঃ', '১', '৯', '৬', '০', '২', 'ং', 'চ', 'ঘ', 'ৎ', '৫', '৪', '‘', '’', 'ফ', 'ৌ', '৮', 'ঁ', 'য়', '৩', 'ঢ', 'ঠ', '৭', ':', '।', '.', 'ড়', 'ঝ', '/', 'ঞ', '\u200c', '\x94', '"', "'", 'ঔ', 'ঈ', '\u200d', 'ঐ', '\x93', 'ঋ', '\n', '\t', '%', '”', 'ঊ', 'ৗ', '–', ';', 'œ', '_', 'ঢ়', '—', '\u200e']
# 120000 ['এ', ' ', 'ধ', 'র', 'ণ', 'ে', 'ক', 'া', '্', 'ড', 'ন', 'ি', 'য', '়', 'হ', 'ত', 'উ', 'প', 'জ', 'অ', 'থ', 'স', 'ব', 'ষ', 'ই', 'আ', 'ছ', 'দ', 'শ', 'গ', 'ু', 'ল', 'ো', 'ও', 'ভ', 'ী', 'ট', 'ূ', 'ম', 'ৈ', 'ৃ', 'ঙ', 'খ', 'ঃ', '১', '৯', '৬', '০', '২', 'ং', 'চ', 'ঘ', 'ৎ', '৫', '৪', '‘', '’', 'ফ', 'ৌ', '৮', 'ঁ', 'য়', '৩', 'ঢ', 'ঠ', '৭', ':', '।', '.', 'ড়', 'ঝ', '/', 'ঞ', '\u200c', '\x94', '"', "'", 'ঔ', 'ঈ', '\u200d', 'ঐ', '\x93', 'ঋ', '\n', '\t', '%', '”', 'ঊ', 'ৗ', '–', ';', 'œ', '_', 'ঢ়', '—', '\u200e']
# ['এ', ' ', 'ধ', 'র', 'ণ', 'ে', 'ক', 'া', '্', 'ড', 'ন', 'ি', 'য', '়', 'হ', 'ত', 'উ', 'প', 'জ', 'অ', 'থ', 'স', 'ব', 'ষ', 'ই', 'আ', 'ছ', 'দ', 'শ', 'গ', 'ু', 'ল', 'ো', 'ও', 'ভ', 'ী', 'ট', 'ূ', 'ম', 'ৈ', 'ৃ', 'ঙ', 'খ', 'ঃ', '১', '৯', '৬', '০', '২', 'ং', 'চ', 'ঘ', 'ৎ', '৫', '৪', '‘', '’', 'ফ', 'ৌ', '৮', 'ঁ', 'য়', '৩', 'ঢ', 'ঠ', '৭', ':', '।', '.', 'ড়', 'ঝ', '/', 'ঞ', '\u200c', '\x94', '"', "'", 'ঔ', 'ঈ', '\u200d', 'ঐ', '\x93', 'ঋ', '\n', '\t', '%', '”', 'ঊ', 'ৗ', '–', ';', 'œ', '_', 'ঢ়', '—', '\u200e', 'ৰ']

# %%
for i in range(0,15):
    listofuniques.pop(0)
print(listofuniques)
# Out:
# ['ঁ', 'ং', 'ঃ', 'অ', 'আ', 'ই', 'ঈ', 'উ', 'ঊ', 'ঋ', 'এ', 'ঐ', 'ও', 'ঔ', 'ক', 'খ', 'গ', 'ঘ', 'ঙ', 'চ', 'ছ', 'জ', 'ঝ', 'ঞ', 'ট', 'ঠ', 'ড', 'ঢ', 'ণ', 'ত', 'থ', 'দ', 'ধ', 'ন', 'প', 'ফ', 'ব', 'ভ', 'ম', 'য', 'র', 'ল', 'শ', 'ষ', 'স', 'হ', '়', 'া', 'ি', 'ী', 'ু', 'ূ', 'ৃ', 'ে', 'ৈ', 'ো', 'ৌ', '্', 'ৎ', 'ৗ', 'ড়', 'ঢ়', 'য়', '০', '১', '২', '৩', '৪', '৫', '৬', '৭', '৮', '৯', 'ৰ', '\u200c', '\u200d', '\u200e', '–', '—', '‘', '’', '”']

# %%
listofuniques.pop(len(listofuniques)-1)
print(listofuniques)
# Out:
# ['ঁ', 'ং', 'ঃ', 'অ', 'আ', 'ই', 'ঈ', 'উ', 'ঊ', 'ঋ', 'এ', 'ঐ', 'ও', 'ঔ', 'ক', 'খ', 'গ', 'ঘ', 'ঙ', 'চ', 'ছ', 'জ', 'ঝ', 'ঞ', 'ট', 'ঠ', 'ড', 'ঢ', 'ণ', 'ত', 'থ', 'দ', 'ধ', 'ন', 'প', 'ফ', 'ব', 'ভ', 'ম', 'য', 'র', 'ল', 'শ', 'ষ', 'স', 'হ', '়', 'া', 'ি', 'ী', 'ু', 'ূ', 'ৃ', 'ে', 'ৈ', 'ো', 'ৌ', '্', 'ৎ', 'ৗ', 'ড়', 'ঢ়', 'য়', '০', '১', '২', '৩', '৪', '৫', '৬', '৭', '৮', '৯', 'ৰ']

# %%
import pandas as pd
slrtsv_path = 'data/openslr_transcript.tsv'
df = pd.read_csv(slrtsv_path, sep='\t')
df
# Out:
#           filename randuid                        banglatrans
# 0       000020a912   16cfb            বাংলাদেশে দায়িত্ব নেবে
# 1       000039928e   976b1                এ ধরণের কার্ড নিয়ে
# 2       00005debc7   f83df                  হতে উপার্জিত অর্থ
# 3       00009e687c   9813c              হাসির বিষয় হয়েই আছে
# 4       00012843bc   7ec1c                    সার্ক দেশগুলোতে
# ...            ...     ...                                ...
# 127560  ffff6a7f59   77f82  সংস্কৃতি মন্ত্রী আবুল কালাম আযাদও
# 127561  ffff98efe5   80539                      অভিযোগ রয়েছে
# 127562  ffffc017a0   15a75             আন্তোনিও দা মাগদালেনার
# 127563  ffffe3b62d   10a9f                          মি. খানের
# 127564  fffff1c677   06e62   কাজী নজরুলের লেখা হিন্দু-মুসলমান
#
# [127565 rows x 3 columns]

# %%
import data_dekhabet as dk
b = dk.banglaletters
d = dk.banglalookup

for index, row in df.head(10).iterrows():
    print('{:02d}: {}'.format(index,row[2]))
    
    for c in row[2]:
        print('{} '.format(c),end='')
    print('')

    sentence = ''
    buffer = ''
    for c in row[2]:
        buffer += c
#         print(c, sentence, len(buffer))
        
        if c == ' ':
            if buffer[len(buffer)-2]=='র' or buffer[len(buffer)-2]=='়':
                sentence = sentence[:-1]
            sentence += d[b.index(c)]
        elif c == '়':
            sentence = sentence[:-2]
            sentence += 'yo'
        elif c in dk.banglanokaars:
            sentence += d[b.index(c)]
        elif c in dk.banglakaars:
            sentence = sentence[:-1]
            sentence += d[b.index(c)]
        elif c == ' ' and buffer[len(buffer)-2]=='র':
            sentence = sentence[:-1]
            sentence += d[b.index(c)]
        else:
            sentence += d[b.index(c)]+'o'
    
    print(sentence,'\n')
# Out:
# 00: বাংলাদেশে দায়িত্ব নেবে
# ব া ং ল া দ ে শ ে   দ া য ় ি ত ্ ব   ন ে ব ে
# ব  1
# া bo 2
# ং ba 3
# ল bang 4
# া banglo 5
# দ bangla 6
# ে banglado 7
# শ banglade 8
# ে bangladesho 9
#   bangladeshe 10
# দ bangladeshe  11
# া bangladeshe do 12
# য bangladeshe da 13
# ় bangladeshe dajo 14
# ি bangladeshe dayo 15
# ত bangladeshe dayi 16
# ্ bangladeshe dayito 17
# ব bangladeshe dayit 18
#   bangladeshe dayitbo 19
# ন bangladeshe dayitbo  20
# ে bangladeshe dayitbo no 21
# ব bangladeshe dayitbo ne 22
# ে bangladeshe dayitbo nebo 23
# bangladeshe dayitbo nebe
#
# 01: এ ধরণের কার্ড নিয়ে
# এ   ধ র ণ ে র   ক া র ্ ড   ন ি য ় ে
# এ  1
#   e 2
# ধ e  3
# র e dho 4
# ণ e dhoro 5
# ে e dhorono 6
# র e dhorone 7
#   e dhoronero 8
# ক e dhoroner  9
# া e dhoroner ko 10
# র e dhoroner ka 11
# ্ e dhoroner karo 12
# ড e dhoroner kar 13
#   e dhoroner kardo 14
# ন e dhoroner kardo  15
# ি e dhoroner kardo no 16
# য e dhoroner kardo ni 17
# ় e dhoroner kardo nijo 18
# ে e dhoroner kardo niyo 19
# e dhoroner kardo niye
#
# 02: হতে উপার্জিত অর্থ
# হ ত ে   উ প া র ্ জ ি ত   অ র ্ থ
# হ  1
# ত ho 2
# ে hoto 3
#   hote 4
# উ hote  5
# প hote u 6
# া hote upo 7
# র hote upa 8
# ্ hote uparo 9
# জ hote upar 10
# ি hote uparjo 11
# ত hote uparji 12
#   hote uparjito 13
# অ hote uparjito  14
# র hote uparjito o 15
# ্ hote uparjito oro 16
# থ hote uparjito or 17
# hote uparjito ortho
#
# 03: হাসির বিষয় হয়েই আছে
# হ া স ি র   ব ি ষ য ়   হ য ় ে ই   আ ছ ে
# হ  1
# া ho 2
# স ha 3
# ি haso 4
# র hasi 5
#   hasiro 6
# ব hasir  7
# ি hasir bo 8
# ষ hasir bi 9
# য hasir bisho 10
# ় hasir bishojo 11
#   hasir bishoyo 12
# হ hasir bishoy  13
# য hasir bishoy ho 14
# ় hasir bishoy hojo 15
# ে hasir bishoy hoyo 16
# ই hasir bishoy hoye 17
#   hasir bishoy hoyei 18
# আ hasir bishoy hoyei  19
# ছ hasir bishoy hoyei a 20
# ে hasir bishoy hoyei achho 21
# hasir bishoy hoyei achhe
#
# 04: সার্ক দেশগুলোতে
# স া র ্ ক   দ ে শ গ ু ল ো ত ে
# স  1
# া so 2
# র sa 3
# ্ saro 4
# ক sar 5
#   sarko 6
# দ sarko  7
# ে sarko do 8
# শ sarko de 9
# গ sarko desho 10
# ু sarko deshogo 11
# ল sarko deshogu 12
# ো sarko deshogulo 13
# ত sarko deshogulo 14
# ে sarko deshoguloto 15
# sarko deshogulote
#
# 05: সহজেই যাওয়া যায়
# স হ জ ে ই   য া ও য ় া   য া য ়
# স  1
# হ so 2
# জ soho 3
# ে sohojo 4
# ই sohoje 5
#   sohojei 6
# য sohojei  7
# া sohojei jo 8
# ও sohojei ja 9
# য sohojei jao 10
# ় sohojei jaojo 11
# া sohojei jaoyo 12
#   sohojei jaoya 13
# য sohojei jaoya  14
# া sohojei jaoya jo 15
# য sohojei jaoya ja 16
# ় sohojei jaoya jajo 17
# sohojei jaoya jayo
#
# 06: অন্তর্ভুক্তও করেছে রাশিয়া
# অ ন ্ ত র ্ ভ ু ক ্ ত ও   ক র ে ছ ে   র া শ ি য ় া
# অ  1
# ন o 2
# ্ ono 3
# ত on 4
# র onto 5
# ্ ontoro 6
# ভ ontor 7
# ু ontorbho 8
# ক ontorbhu 9
# ্ ontorbhuko 10
# ত ontorbhuk 11
# ও ontorbhukto 12
#   ontorbhuktoo 13
# ক ontorbhuktoo  14
# র ontorbhuktoo ko 15
# ে ontorbhuktoo koro 16
# ছ ontorbhuktoo kore 17
# ে ontorbhuktoo korechho 18
#   ontorbhuktoo korechhe 19
# র ontorbhuktoo korechhe  20
# া ontorbhuktoo korechhe ro 21
# শ ontorbhuktoo korechhe ra 22
# ি ontorbhuktoo korechhe rasho 23
# য ontorbhuktoo korechhe rashi 24
# ় ontorbhuktoo korechhe rashijo 25
# া ontorbhuktoo korechhe rashiyo 26
# ontorbhuktoo korechhe rashiya
#
# 07: সুরকার হিসেবে
# স ু র ক া র   হ ি স ে ব ে
# স  1
# ু so 2
# র su 3
# ক suro 4
# া suroko 5
# র suroka 6
#   surokaro 7
# হ surokar  8
# ি surokar ho 9
# স surokar hi 10
# ে surokar hiso 11
# ব surokar hise 12
# ে surokar hisebo 13
# surokar hisebe
#
# 08: যাতে বিবাহ শাদী দিলে
# য া ত ে   ব ি ব া হ   শ া দ ী   দ ি ল ে
# য  1
# া jo 2
# ত ja 3
# ে jato 4
#   jate 5
# ব jate  6
# ি jate bo 7
# ব jate bi 8
# া jate bibo 9
# হ jate biba 10
#   jate bibaho 11
# শ jate bibaho  12
# া jate bibaho sho 13
# দ jate bibaho sha 14
# ী jate bibaho shado 15
#   jate bibaho shadi 16
# দ jate bibaho shadi  17
# ি jate bibaho shadi do 18
# ল jate bibaho shadi di 19
# ে jate bibaho shadi dilo 20
# jate bibaho shadi dile
#
# 09: আপনার গল্প ছাড়া
# আ প ন া র   গ ল ্ প   ছ া ড ় া
# আ  1
# প a 2
# ন apo 3
# া apono 4
# র apona 5
#   aponaro 6
# গ aponar  7
# ল aponar go 8
# ্ aponar golo 9
# প aponar gol 10
#   aponar golpo 11
# ছ aponar golpo  12
# া aponar golpo chho 13
# ড aponar golpo chha 14
# ় aponar golpo chhado 15
# া aponar golpo chhayo 16
# aponar golpo chhaya
